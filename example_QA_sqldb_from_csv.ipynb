# %% [markdown]
# # SQL Agent - Real Estate Database
#
# This notebook serves as a simple demonstration of the core capabilities of the SQL agent. It is inspired by the repository at [Advanced QA and RAG Series](https://github.com/Farzad-R/Advanced-QA-and-RAG-Series?tab=readme-ov-file#Q&A-and-RAG-with-SQL-and-TabularData).
#
# In this example, I load a subset of the data, consisting of 1,000 properties, focusing on a few columns that represent the most basic features.
#
# I then use a SQL agent from LangChain ([documentation](https://api.python.langchain.com/en/latest/agent_toolkits/langchain_community.agent_toolkits.sql.base.create_sql_agent.html)) to query the data. To ensure the accuracy of the results, I also verify the queries using Pandas.

# %%
import pandas as pd
from pyprojroot import here

# %%
df = pd.read_csv(here("data/for_upload/properties_information_basic_features.csv"))
print(df.shape)
print(df.columns.tolist())
display(df.head(3))
# Out:
# (1000, 19)
# ['zpid', 'city', 'state', 'homeStatus', 'streetAddress', 'zipcode', 'bedrooms', 'bathrooms', 'price', 'longitude', 'latitude', 'homeType', 'lotSize', 'zestimate', 'rentZestimate', 'dateSoldString', 'taxAssessedValue', 'taxAssessedYear', 'parcelId']
#        zpid       city state homeStatus           streetAddress  zipcode  \
# 0  63662682      Greer    SC       SOLD  1008 Carriage Park Cir    29650
# 1   5716098  Lexington    NC       SOLD       1309 Riverwood Dr    27292
# 2  29134937  Arlington    TX       SOLD        1418 Cardinal St    76010
#
#    bedrooms  bathrooms   price  longitude   latitude       homeType  lotSize  \
# 0       4.0        3.0  415000  -82.27929  34.867980  SINGLE_FAMILY   9583.0
# 1       3.0        3.0  375000  -80.29264  35.654854  SINGLE_FAMILY  80586.0
# 2       4.0        2.0       0  -97.08692  32.724987  SINGLE_FAMILY   9147.0
#
#    zestimate  rentZestimate dateSoldString  taxAssessedValue  taxAssessedYear  \
# 0   581300.0           3153     2021-09-28          402970.0           2023.0
# 1   447100.0           1900     2022-09-02          262980.0           2023.0
# 2   240000.0           1802     2022-05-25          213321.0           2023.0
#
#            parcelId
# 0     0534410100500
# 1  06036L0000006000
# 2          03243176

# %% [markdown]
# ### **SQL**
#
#
# Most SQL databases make it easy to load a CSV file in as a table (DuckDB, SQLite, etc.). Once you’ve done this you can use all of the chain and agent-creating techniques outlined in the SQL use case guide. Here’s a quick example of how we might do this with SQLite:

# %%
from langchain_community.utilities import SQLDatabase
from sqlalchemy import create_engine
db_path = str(here("data")) + "/csv_xlsx_sqldb.db"
db_path = f"sqlite:///{db_path}"

engine = create_engine(db_path)
# df.to_sql("titanic", engine, index=False)
df.to_sql("properties", engine, index=False)

# %% [markdown]
# For multiple csv files, we can create a sql with multiple tables:
# ```
# df1.to_sql("csv1_name", engine, index=False)
# df2.to_sql("csv2_name", engine, index=False)
# ```

# %% [markdown]
# **Lets make a test Query**

# %%
db = SQLDatabase(engine=engine)
print(db.dialect)
print(db.get_usable_table_names())
db.run("SELECT * FRO
 'WA', 'OTHER', '713 Marine Dr', 98281, 2.0, 1.0, 1126200, -123.08283, 48.97714, 'SINGLE_FAMILY', 54450.0, 1126200.0, 3818, '1996-05-01', 1064848.0, 2023.0, '4053095044210000'), (48915032, 'Bellevue', 'WA', 'RECENTLY_SOLD', '16851 NE 14th Place', 98008, 4.0, 3.0, 1407500, -122.115555, 47.622723, 'SINGLE_FAMILY', 9652.0, 1472800.0, 3999, '2023-10-31', 972000.0, 2023.0, '4040700300'), (23553667, 'Spokane', 'WA', 'OTHER', '1318 E Wabash Ave', 99207, 3.0, 1.0, 262700, -117.39035, 47.70197, 'SINGLE_FAMILY', 5227.0, 262700.0, 1500, '2012-05-30', 212500.0, 2022.0, '363241603'), (63335985, 'Issaquah', 'WA', 'OTHER', '23120 SE Black Nugget Rd UNIT D1', 98029, 4.0, 3.25, 979200, -122.03075, 47.548565, 'CONDO', 185577.0, 979200.0, 3599, '2003-09-05', 1042000.0, 2023.0, '3067000150'), (23508681, 'Spokane', 'WA', 'RECENTLY_SOLD', '4517 N Lidgerwood St', 99207, 1.0, 1.0, 171000, -117.40632, 47.69962, 'SINGLE_FAMILY', 5000.0, 171600.0, 1170, '2024-04-30', 189600.0, 2023.0, '350520628'), (67977549, 'Tacoma', 'WA', 'RECENTLY_SOLD', '2958 S Proctor Street', 98409, 2.0, 3.0, 360000, -122.488884, 47.233875, 'TOWNHOUSE', 2866.0, 364900.0, 2420, '2024-03-20', 314000.0, 2023.0, '9005610020'), (82576447, 'Ellensburg', 'WA', 'OTHER', '905 W Cascade Ct UNIT 32', 98926, None, 2.0, 153800, -120.56186, 47.00287, 'SINGLE_FAMILY', 924.0, 153800.0, 635, '2012-05-18', 7730.0, 2022.0, '17650'), (23619360, 'Bellingham', 'WA', 'OTHER', '3028 Elm St', 98225, 1.0, 1.0, 456800, -122.48803, 48.77055, 'SINGLE_FAMILY', 4791.0, 456800.0, 1500, '2003-07-02', 458485.0, 2023.0, '3802245193930000'), (55201706, 'Auburn', 'WA', ...

# %% [markdown]
# **Equivalent in Pandas**

# %%
df[df['state'] == 'WA']
# Out:
#           zpid           city state     homeStatus  \
# 4     49400095        Rainier    WA          OTHER
# 23    23232081      Vancouver    WA          OTHER
# 80    23610252     Bellingham    WA          OTHER
# 190   67024958          Kelso    WA          OTHER
# 200   49258449       Spanaway    WA  RECENTLY_SOLD
# 209   67013600       Longview    WA       FOR_SALE
# 252   38611480        Everett    WA           SOLD
# 303   49324498       Puyallup    WA          OTHER
# 441   96678923       Bellevue    WA          OTHER
# 553  102645854       Spanaway    WA           SOLD
# 581   49247236         Tacoma    WA          OTHER
# 585   23289824      Vancouver    WA          OTHER
# 599   23667850  Point Roberts    WA          OTHER
# 606   48915032       Bellevue    WA  RECENTLY_SOLD
# 614   23553667        Spokane    WA          OTHER
# 626   63335985       Issaquah    WA          OTHER
# 656   23508681        Spokane    WA  RECENTLY_SOLD
# 673   67977549         Tacoma    WA  RECENTLY_SOLD
# 707   82576447     Ellensburg    WA          OTHER
# 733   23619360     Bellingham    WA          OTHER
# 747   55201706         Auburn    WA          OTHER
# 786  284883366   Lake Stevens    WA          OTHER
# 796   49293184       Lakewood    WA          OTHER
# 811   99372591    Bonney Lake    WA          OTHER
# 813   80118002    Woodinville    WA          OTHER
# 818   48960953         Auburn    WA  RECENTLY_SOLD
# 835   79531363        Spokane    WA          OTHER
# 873  112551265  Port Townsend    WA          OTHER
# 935   48847449        Seattle    WA          OTHER
# 955  112548439    Port Ludlow    WA          OTHER
# 988   49164682     Gig Harbor    WA          OTHER
#
#                         streetAddress  zipcode  bedrooms  bathrooms    price  \
# 4                   802 Tipsoo Loop S    98576       3.0       1.25   469900
# 23                      3517 Grant St    98660       2.0       1.00   446900
# 80                     66 Marigold Dr    98229       3.0       3.00   916500
# 190                     709 S 5th Ave    98626       2.0       1.00   283900
# 200               21818 42nd Avenue E    98387       5.0       3.00   535000
# 209                 1 Monterrey Place    98632       3.0       3.00   579900
# 252      1427 100th Street SW UNIT 40    98204       3.0       2.00   185000
# 303           14715 105th Avenue Ct E    98374       3.0       1.75   489000
# 441                 7011 172nd Ave SE    98006       5.0       4.25  3538300
# 553               1619 177th Street E    98387       3.0       3.00   485000
# 581                   648 S Howard St    98465       2.0       1.00   386200
# 585         11910 SE McGillivray Blvd    98683       4.0       3.00   499600
# 599                     713 Marine Dr    98281       2.0       1.00  1126200
# 606               16851 NE 14th Place    98008       4.0       3.00  1407500
# 614                 1318 E Wabash Ave    99207       3.0       1.00   262700
# 626  23120 SE Black Nugget Rd UNIT D1    98029       4.0       3.25   979200
# 656              4517 N Lidgerwood St    99207       1.0       1.00   171000
# 673             2958 S Proctor Street    98409       2.0       3.00   360000
# 707          905 W Cascade Ct UNIT 32    98926       NaN       2.00   153800
# 733                       3028 Elm St    98225       1.0       1.00   456800
# 747             1129 61st St SE #D-16    98092       2.0       2.00   354800
# 786                  2121 101st Dr SE    98258       4.0       3.00   928000
# 796         8804 Frances Folsom St SW    98498       3.0       2.00  1439800
# 811                 13522 188th Ave E    98391       3.0       2.50   708700
# 813                20341 134th Ave NE    98072       4.0       3.50  1435000
# 818                  1809 C Street SE    98002       4.0       4.00   550000
# 835                     3707 W Jay St    99208       4.0       3.00   555800
# 873                    4330 Lopez Ave    98368       3.0       2.00   602100
# 935           130 NE 95th St APT A206    98115       2.0       2.00   436200
# 955                    121 Mariner Pl    98365       3.0       3.00   782800
# 988           2710 120th Street Ct NW    98332       3.0       2.25   732300
#
#       longitude   latitude       homeType   lotSize  zestimate  rentZestimate  \
# 4   -122.683180  46.899750   MANUFACTURED   67082.0   469900.0           2114
# 23  -122.677950  45.647530  SINGLE_FAMILY    5349.0   446900.0           1994
# 80  -122.321144  48.714054  SINGLE_FAMILY       NaN   916500.0           2614
# 606     2023-10-31          972000.0           2023.0        4040700300
# 614     2012-05-30          212500.0           2022.0         363241603
# 626     2003-09-05         1042000.0           2023.0        3067000150
# 656     2024-04-30          189600.0           2023.0         350520628
# 673     2024-03-20          314000.0           2023.0        9005610020
# 707     2012-05-18            7730.0           2022.0             17650
# 733     2003-07-02          458485.0           2023.0  3802245193930000
# 747     2019-05-22          288200.0           2023.0        9003560140
# 786     2021-03-11          797100.0           2023.0    01173900003600
# 796     2006-12-05         1155900.0           2023.0        6385300380
# 811     2013-07-17          586500.0           2023.0        7002260380
# 813     2018-06-20         1053000.0           2023.0        2738640130
# 818     2024-01-19          566000.0           2023.0        5422400070
# 835     2007-04-25          519900.0           2023.0         262321011
# 873     2012-06-29          478141.0           2022.0         992300018
# 935     2015-10-11          408000.0           2023.0        3130900150
# 955     2018-04-09          662859.0           2022.0         931900008
# 988     2012-07-30          643600.0           2023.0        0222295003

# %% [markdown]
# ### **Create an agent to interact with the Database**

# %% [markdown]
# Load credentials. Here we're utilizing an OpenAI model through Azure.

# %%
import os
from dotenv import load_dotenv
import warnings
warnings.filterwarnings("ignore")
print("Environment variables are loaded:", load_dotenv())
print("test by reading a variable:", os.getenv("OPENAI_API_TYPE"))
# Out:
# Environment variables are loaded: True
# test by reading a variable: azure

# %%
from langchain.chat_models import AzureChatOpenAI

model_name = os.getenv("gpt_deployment_name")
azure_openai_api_key = os.environ["OPENAI_API_KEY"]
azure_openai_endpoint = os.environ["OPENAI_API_BASE"]
llm = AzureChatOpenAI(
    openai_api_version=os.getenv("OPENAI_API_VERSION"),
    azure_deployment=model_name,
    model_name=model_name,
    temperature=0.0)
# Out:
# c:\Users\danielcarvalho.dcf\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\_api\deprecation.py:141: LangChainDeprecationWarning: The class `AzureChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import AzureChatOpenAI`.
#   warn_deprecated(

# %% [markdown]
# Now, let's run a test by querying the agent for properties located in Florida and Washington State.

# %%
from langchain_community.agent_toolkits import create_sql_agent
agent_executor = create_sql_agent(llm, db=db, verbose=True)

# %%
agent_executor.invoke({"input": "List the total houses in washington state and florida. also list the average price?"})
# Out:
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: ""properties, properties_informationI should query the schema of the properties and properties_information tables to see what columns I can use to answer the question.
# Action: sql_db_schema
# Action Input: properties, properties_information
# CREATE TABLE properties (
# 	zpid BIGINT,
# 	city TEXT,
# 	state TEXT,
# 	"homeStatus" TEXT,
# 	"streetAddress" TEXT,
# 	zipcode BIGINT,
# 	bedrooms FLOAT,
# 	bathrooms FLOAT,
# 	price BIGINT,
# 	longitude FLOAT,
# 	latitude FLOAT,
# 	"homeType" TEXT,
# 	"lotSize" FLOAT,
# 	zestimate FLOAT,
# 	"rentZestimate" BIGINT,
# 	"dateSoldString" TEXT,
# 	"taxAssessedValue" FLOAT,
# 	"taxAssessedYear" FLOAT,
# 	"parcelId" TEXT
# )
#
# /*
# 3 rows from properties table:
# zpid	city	state	homeStatus	streetAddress	zipcode	bedrooms	bathrooms	price	longitude	latitude	homeType	lotSize	zestimate	rentZestimate	dateSoldString	taxAssessedValue	taxAssessedYear	parcelId
# 63662682	Greer	SC	SOLD	1008 Carriage Park Cir	29650	4.0	3.0	415000	-82.27929	34.86798	SINGLE_FAMILY	9583.0	581300.0	3153	2021-09-28	402970.0	2023.0	0534410100500
# 5716098	Lexington	NC	SOLD	1309 Riverwood Dr	27292	3.0	3.0	375000	-80.29264	35.654854	SINGLE_FAMILY	80586.0	447100.0	1900	2022-09-02	262980.0	2023.0	06036L0000006000
# 29134937	Arlington	TX	SOLD	1418 Cardinal St	76010	4.0	2.0	0	-97.08692	32.724987	SINGLE_FAMILY	9147.0	240000.0	1802	2022-05-25	213321.0	2023.0	03243176
# */
#
#
# CREATE TABLE properties_information (
# 	zpid BIGINT,
# 	city TEXT,
# 	state TEXT,
# 	"homeStatus" TEXT,
# 	"streetAddress" TEXT,
# 	zipcode BIGINT,
# 	bedrooms FLOAT,
# 	bathrooms FLOAT,
# 	price BIGINT,
# 	longitude FLOAT,
# 	latitude FLOAT,
# 	"homeType" TEXT,
# 	"lotSize" FLOAT,
# 	zestimate FLOAT,
# 	"rentZestimate" BIGINT,
# 	"dateSoldString" TEXT,
# 	"taxAssessedValue" FLOAT,
# 	"taxAssessedYear" FLOAT,
# 	"parcelId" TEXT
# )
#
# /*
# 3 rows from properties_information table:
# zpid	city	state	homeStatus	streetAddress	zipcode	bedrooms	bathrooms	price	longitude	latitude	homeType	lotSize	zestimate	rentZestimate	dateSoldString	taxAssessedValue	taxAssessedYear	parcelId
# 63662682	Greer	SC	SOLD	1008 Carriage Park Cir	29650	4.0	3.0	415000	-82.27929	34.86798	SINGLE_FAMILY	9583.0	581300.0	3153	2021-09-28	402970.0	2023.0	0534410100500
# 5716098	Lexington	NC	SOLD	1309 Riverwood Dr	27292	3.0	3.0	375000	-80.29264	35.654854	SINGLE_FAMILY	80586.0	447100.0	1900	2022-09-02	262980.0	2023.0	06036L0000006000
# 29134937	Arlington	TX	SOLD	1418 Cardinal St	76010	4.0	2.0	0	-97.08692	32.724987	SINGLE_FAMILY	9147.0	240000.0	1802	2022-05-25	213321.0	2023.0	03243176
# */I should query the properties table to get the total houses in Washington state and Florida, and the average price.
# Action: sql_db_query
# Action Input: "SELECT state, COUNT(*) as total_houses, AVG(price) as avg_price FROM properties WHERE state IN ('WA', 'FL') GROUP BY state"[('FL', 124, 557047.4596774194), ('WA', 31, 717996.7741935484)]I now know the final answer.
# Final Answer: There are 31 houses in Washington state and 124 houses in Florida, with an average price of $717,996.77 and $557,047.46, respectively.
#
# > Finished chain.
# {'input': 'List the total houses in washington state and florida. also list the average price?',
#  'output': 'There are 31 houses in Washington state and 124 houses in Florida, with an average price of $717,996.77 and $557,047.46, respectively.'}

# %% [markdown]
# in the output we can look at the agent Query:
#
# SELECT
#
# state,
#
# COUNT(*) as total_houses,
#
# AVG(price) as avg_price
#
# FROM properties
#
# WHERE state IN ('WA', 'FL')
# GROUP BY state

# %% [markdown]
# Let's check the answer with Pandas

# %%
filtered_df = df[df['state'].isin(['WA', 'FL'])]

# Group by 'state' and calculate the count and average price
result = filtered_df.groupby('state')['price'].agg(['count', 'mean']).reset_index()

# Rename the columns for clarity
result.columns = ['State', 'Property Count', 'Average Price']

# Display the result
result
# Out:
#   State  Property Count  Average Price
# 0    FL             124  557047.459677
# 1    WA              31  717996.774194

# %% [markdown]
# Let's introduce some typos to see if the agent/LLM can handle it.
#
# Let's also see if the agent understands that we now need the average considering both states at the same time.

# %%
agent_executor.invoke({"input": "what's the average price in washignto satete and floreida?"})
# Out:
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: ""properties, properties_informationI should query the schema of the properties table to see if it has a price column.
# Action: sql_db_schema
# Action Input: properties
# CREATE TABLE properties (
# 	zpid BIGINT,
# 	city TEXT,
# 	state TEXT,
# 	"homeStatus" TEXT,
# 	"streetAddress" TEXT,
# 	zipcode BIGINT,
# 	bedrooms FLOAT,
# 	bathrooms FLOAT,
# 	price BIGINT,
# 	longitude FLOAT,
# 	latitude FLOAT,
# 	"homeType" TEXT,
# 	"lotSize" FLOAT,
# 	zestimate FLOAT,
# 	"rentZestimate" BIGINT,
# 	"dateSoldString" TEXT,
# 	"taxAssessedValue" FLOAT,
# 	"taxAssessedYear" FLOAT,
# 	"parcelId" TEXT
# )
#
# /*
# 3 rows from properties table:
# zpid	city	state	homeStatus	streetAddress	zipcode	bedrooms	bathrooms	price	longitude	latitude	homeType	lotSize	zestimate	rentZestimate	dateSoldString	taxAssessedValue	taxAssessedYear	parcelId
# 63662682	Greer	SC	SOLD	1008 Carriage Park Cir	29650	4.0	3.0	415000	-82.27929	34.86798	SINGLE_FAMILY	9583.0	581300.0	3153	2021-09-28	402970.0	2023.0	0534410100500
# 5716098	Lexington	NC	SOLD	1309 Riverwood Dr	27292	3.0	3.0	375000	-80.29264	35.654854	SINGLE_FAMILY	80586.0	447100.0	1900	2022-09-02	262980.0	2023.0	06036L0000006000
# 29134937	Arlington	TX	SOLD	1418 Cardinal St	76010	4.0	2.0	0	-97.08692	32.724987	SINGLE_FAMILY	9147.0	240000.0	1802	2022-05-25	213321.0	2023.0	03243176
# */I can query the price column from the properties table for properties in Washington state and Florida, then calculate the average.
# Action: sql_db_query
# Action Input: "SELECT AVG(price) FROM properties WHERE state='WA' OR state='FL' LIMIT 10"[(589237.3225806452,)]The average price in Washington state and Florida is $589,237.32.
# Final Answer: The average price in Washington state and Florida is $589,237.32.
#
# > Finished chain.
# {'input': "what's the average price in washignto satete and floreida?",
#  'output': 'The average price in Washington state and Florida is $589,237.32.'}

# %%
filtered_df = df[df['state'].isin(['WA', 'FL'])]

# Calculate the overall average price for WA and FL combined
overall_avg_price = filtered_df['price'].mean()

# Display the result
print(f"The overall average price for properties in WA and FL is: ${overall_avg_price:.2f}")
# Out:
# The overall average price for properties in WA and FL is: $589237.32
